# %%
from faces import *
faces_data = get_lfw_data()
# Out:
# Total dataset size:
# 	num_samples: 1867
# 	num_features: 1850
# 	num_classes: 19

# %%
show_image(faces_data[0])
show_image(faces_data[1])
show_image(faces_data[2])
show_image(faces_data[23])
show_image(faces_data[24])
show_image(faces_data[25])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-93255f7f7346> in <module>()
#       1 show_image(faces_data[0])
#       2 show_image(faces_data[1])
# ----> 3 show_image(faces_data[2])
#       4 show_image(faces_data[23])
#       5 show_image(faces_data[24])
#
# IndexError: tuple index out of range
